# %% [markdown]
# # Wooden Spoons
#
# ## Introduction
#
# This notebook is an analysis of wooden spoons in tennis.
#
# The wooden spoon is a statistical booby prize that any early loser in a single-elimination tournament can earn. The winner of the wooden spoon is a player who is defeated by another player in the first round, who is then defeated by another player in the second, who is then defeated by someone else in the third, and so on, all the way up to the finalist (who loses the tournament champion in the final). Unlikely as it sounds at first, just as every tournament always has exactly one champion, it always has exactly one wooden spoon!
#
# Whereas the champion sits atop the longest possible list of wins, the holder of the wooden spoon sits beneath the longest possible list of losses. Therefore if the champion of the tournament is supposedly the best player there, then logically the holder of the wooden spoon is the worst.
#
# However, this is only really true if matches are deterministic, and the winner of each match is always the better of the two players. In reality, there is a lot of randomness involved (just enough to make the sport exiting). In almost every sport even top-ranked players are statistically likely to eat a shock first-round exit from time to time.
#
# The women's tennis world recently got a particularly interesting wooden spoon holder. The highest tier of tennis tournaments are the Grand Slams, four of which are held every year. [Jeļena Ostapenko](https://en.wikipedia.org/wiki/Je%C4%BCena_Ostapenko), an aggressive, hard-hitting Latvian player, shook things up in 2017 by winning one of them, the French Open, prevailing over overwhelming favorite [Simona Halep](https://en.wikipedia.org/wiki/Simona_Halep) in the final to secure the first French Cup win by an unseeded (low-ranked) player since 1933.
#
# Well, the French Open came and went again, and this year we saw defending champion Ostapenko win...a wooden spoon.
#
# The best player at the tournament in 2017, worst player in 2018. A slam and an anti-slam, in the same event, back to back! Impressive.
#
# This got me thinking. Who are the wooden spoon holders? How often do top-ranking players earn them? [The best list I could find](http://www.mikero.com/misc/anti-slam/) is several years out of date, and only covers the ATP. [The data](https://github.com/JeffSackmann) is out there, courtesy of Jeff Sackmann. Is there anything to the wooden spoon?

# %% [markdown]
# ## Data processing
#
# Raw data via https://github.com/JeffSackmann/tennis_wta and https://github.com/JeffSackmann/tennis_atp, downloaded, unzipped, and deposited into a `data` local folder for this repository. Thanks Jeff!

# %%
# %ls ../data
# Out:
# tennis_atp-master/  tennis_wta-master/

# %%
pd.set_option('max_columns', None)

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

atp = pd.concat([pd.read_csv('../data/tennis_atp-master/atp_matches_{0}.csv'.format(year)) for year in tqdm(range(1968, 2019))])
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
#
#  16%|█▌        | 8/51 [00:00<00:00, 79.45it/s]
#
#  29%|██▉       | 15/51 [00:00<00:00, 69.75it/s]
#
#  43%|████▎     | 22/51 [00:00<00:00, 67.86it/s]
#
#  55%|█████▍    | 28/51 [00:00<00:00, 64.21it/s]
#
#  67%|██████▋   | 34/51 [00:00<00:00, 62.58it/s]
#
#  78%|███████▊  | 40/51 [00:00<00:00, 62.04it/s]
#
#  92%|█████████▏| 47/51 [00:00<00:00, 61.96it/s]
#
# 100%|██████████| 51/51 [00:00<00:00, 62.19it/s]

# %%
atp.shape
# Out:
# (167879, 49)

# %% [markdown]
# Focus on the Slams.

# %%
atp_slams = atp[atp['tourney_name'].isin(['Wimbledon', 'Roland Garros', 'US Open', 'Us Open', 'Australian Open'])]

# %%
atp_slams.shape
# Out:
# (24062, 49)

# %%
atp_slams.head()
# Out:
#     tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 223   1968-560      US Open   Grass         96             G      19680829
# 224   1968-560      US Open   Grass         96             G      19680829
# 225   1968-560      US Open   Grass         96             G      19680829
# 226   1968-560      US Open   Grass         96             G      19680829
# 227   1968-560      US Open   Grass         96             G      19680829
#
#      match_num  winner_id  winner_seed winner_entry          winner_name  \
# 223          1     100087          4.0          NaN        John Newcombe
# 224          2     100023          NaN          NaN  Ramanathan Krishnan
# 225          3     109816          NaN          NaN      E Victor Seixas
# 226          4     109932          NaN          NaN     Charles Mckinley
# 227          5     100060         15.0          NaN        Marty Riessen
#
#     winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 223           R      183.0        AUS   24.268309          NaN
# 224           R        NaN        IND   31.383984          NaN
# 225           R      185.0        USA   44.999316          NaN
# 226           R        NaN        USA   27.646817          NaN
# 227           R      185.0        USA   26.735113          NaN
#
#      winner_rank_points  loser_id  loser_seed loser_entry         loser_name  \
# 223                 NaN    110066         NaN         NaN         Allen Quay
# 224                 NaN    109966         NaN         NaN     Warren Jacques
# 225                 NaN    100127         NaN         NaN         Tom Gorman
# 226                 NaN    109982         NaN         NaN        William Tym
# 227                 NaN    100141         NaN         NaN  Zeljko Franulovic
#
#     loser_hand  loser_ht loser_ioc  loser_age  loser_rank  loser_rank_points  \
# 223          R       NaN       USA        NaN         NaN                NaN
# 224          R       NaN       AUS  30.472279         NaN                NaN
# 225          R     180.0       USA  21.694730         NaN                NaN
# 226          R       NaN       USA        NaN         NaN                NaN
# 227          R       NaN       CRO  21.212868         NaN                NaN
#
#                    score  best_of round  minutes  w_ace  w_df  w_svpt  \
# 223          6-1 6-3 6-3        5  R128      NaN    NaN   NaN     NaN
# 224    14-12 2-6 6-0 6-4        5  R128      NaN    NaN   NaN     NaN
# 225          8-6 6-4 6-3        5  R128      NaN    NaN   NaN     NaN
# 226  6-3 8-6 2-6 3-6 6-1        5  R128      NaN    NaN   NaN     NaN
# 227     11-9 4-6 6-3 6-4        5  R128      NaN    NaN   NaN     NaN
#
#      w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  \
# 223      NaN       NaN       NaN      NaN        NaN        NaN    NaN   NaN
# 224      NaN       NaN       NaN      NaN        NaN        NaN    NaN   NaN
# 225      NaN       NaN       NaN      NaN        NaN        NaN    NaN   NaN
# 226      NaN       NaN       NaN      NaN        NaN        NaN    NaN   NaN
# 227      NaN       NaN       NaN      NaN        NaN        NaN    NaN   NaN
#
#      l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced
# 223     NaN      NaN       NaN       NaN      NaN        NaN        NaN
# 224     NaN      NaN       NaN       NaN      NaN        NaN        NaN
# 225     NaN      NaN       NaN       NaN      NaN        NaN        NaN
# 226     NaN      NaN       NaN       NaN      NaN        NaN        NaN
# 227     NaN      NaN       NaN       NaN      NaN        NaN        NaN

# %%
atp_slams['round'].value_counts()
# Out:
# R128    11628
# R64      6265
# R32      3184
# R16      1592
# QF        796
# SF        398
# F         199
# Name: round, dtype: int64

# %%
def spoon(tourney):
    round_order = ['R128', 'R64', 'R32', 'R16', 'QF', 'SF', 'F']
    
    try:
        latest_loser = tourney.query("round == 'F'").iloc[0].loser_name
    except IndexError:
        # Partial data. Occurs occassionally.
        print("WARNING: could not parse data for tourney {0} with timestamp {1}".format(
            tourney.tourney_name.iloc[0], tourney.tourney_date.iloc[0]
        ))
        return ("Unknown", "Unseeded")
    
    latest_round = 'F'
    for r in round_order[:-1][::-1]:
        try:
            latest_loser = tourney.query("round == '{0}'".format(r)).query("winner_name == '{0}'".format(latest_loser)).iloc[0].loser_name
            latest_round = r
        except IndexError:
            break
            
    if pd.isnull(latest_loser):
        return ("Unknown", "Unseeded")
    
    else:
        seed = tourney.query("loser_name == '{0}'".format(latest_loser)).iloc[0].loser_seed
        if pd.isnull(seed):
            seed = "Unseeded"
        else:
            seed = "[" + str(int(seed)) + "]"
            
        return latest_loser, seed

# %%
atp_slam_spoons = (
    atp_slams
        .groupby(['tourney_name', 'tourney_date'])
        .apply(lambda df: " ".join(spoon(df)))
        .reset_index()
        # Grab just the year from the int-formatted start date.
        .pipe(lambda df: df.assign(tourney_date=df.tourney_date.map(lambda v: str(v)[:4]).astype(int)))
        .rename(columns={'tourney_date': 'Year', 'tourney_name': 'Tournament', 0: 'Player'})
        # Recent US Opens are 'Us Open' for some reason.
        .replace('Us Open', 'US Open')
        # To maintain consistency with WTA list.
        .replace('Roland Garros', 'French Open')
        # Deal with doubled entries. The Australian was contested twice a couple of times due to calendar changes.
        # cf. http://www.mikero.com/misc/anti-slam/
        .groupby(['Tournament', 'Year'])
        .first()
        .unstack('Tournament')
        .replace(np.nan, 'Unknown')
        .applymap(lambda v: v.replace(" Unseeded", ""))
)

# %%
atp_slam_spoons
# Out:
#                              Player                          \
# Tournament          Australian Open             French Open
# Year
# 1968                        Unknown            Joseph Mateo
# 1969                   Bob Giltinan             Ivan Molina
# 1970                Anthony Hammond  Jean Francois Caujolle
# 1971                 Alvin Gardiner            Bob Giltinan
# 1972                       Jun Kuki              Ion Tiriac
# 1973              Robert Casey C100              Piero Toci
# 1974                     John James        Michele Leclercq
# 1975                    Joao Soares        Patricio Cornejo
# 1976                        Unknown            Chris Kachel
# 1977                    Allan Stone            Chris Kachel
# 1978                  Richard Lewis             Jiri Granat
# 1979                  George Hardie           Bernard Fritz
# 1980                    Jay Lapidus         Bernard Boileau
# 1981                Chris Johnstone          Mark Edmondson
# 1982                 Jonathan Smith             Tim Mayotte
# 1983           Henrik Sundstrom [9]       Jose Luis Damiani
# 1984                Russell Simpson              Matt Doyle
# 1985                Mark Wooldridge       Shlomo Glickstein
# 1986                        Unknown            Victor Pecci
# 1987                John Fitzgerald          Peter Lundgren
# 1988                    Larry Scott            Sergio Casal
# 1989                  Michael Kures           Tore Meinecke
# 1990                 Kelly Evernden         Guillaume Raoux
# 1991                   Peter Doohan            Jeff Tarango
# 1992                Karsten Braasch          Javier Sanchez
# 1993                    Grant Doyle          Nicolas Escude
# 1994                  John Sullivan          Grant Stafford
# 1995           Goran Ivanisevic [4]             Hernan Gumy
# 1996                 Jonathan Stark        Nicolas Lapentti
# 1997        Juan Albert Viloca Puig  Emilio Benfele Alvarez
# 1998              Marcelo Filippini          Javier Sanchez
# 1999                Joseph Sirianni       Karol Kucera [11]
# 2000            Cedric Pioline [13]             Galo Blanco
# 2001                  David Sanchez             Martin Damm
# 2002                 Flavio Saretta         Max Mirnyi [26]
# 2003                   Hicham Arazi        Justin Gimelstob
# 2004          Rainer Schuettler [6]       Joachim Johansson
# 2005                 Felix Mantilla         Fabrice Santoro
# 2006               Fernando Vicente           Oliver Marach
# 2007                     Luis Horna   Fernando Gonzalez [5]
# 2008                   Donald Young          Viktor Troicki
# 2009                Kristof Vliegen             Yen Hsun Lu
# 2010                    Robin Haase       Rainer Schuettler
# 2011               Denis Gremelmayr           Daniel Brands
# 2012                  Gilles Muller             Eric Prodon
# 2013                Tommy Haas [19]             Denis Kudla
# 2014              Federico Delbonis         Albert Montanes
# 2015                    Blaz Kavcic            Maxime Hamou
# 2016               Rafael Nadal [5]        Julien Benneteau
# 2017           Feliciano Lopez [28]           Damir Dzumhur
# 2018             Stefanos Tsitsipas                 Unknown
#
#
# Tournament                 US Open                Wimbledon
# Year
# 1968                  Billy Knight            Lance Lumsden
# 1969                   David Lloyd             Bob Giltinan
# 1970                    Onny Parun         Szabolcz Baranyi
# 1971             D Richard Russell               Pat Cramer
# 1972                     Pat Dupre              Jim Osborne
# 1973                 Rayno Seegers             Neale Fraser
# 1974                Jun Kamiwazumi              Peter Szoke
# 1975            Howard Schoenfield             John Andrews
# 1976             Ove Nils Bengtson              Jay Royappa
# 1977                  Ricardo Cano            Mike Machette
# 1978                  George Amaya        John Mcenroe [11]
# 1979          Adriano Panatta [15]               John Yuill
# 1980                 George Hardie            Byron Bertram
# 1981                    Bill Cowan                Phil Dent
# 1982                 Eddie Edwards               Rick Fagel
# 1983                   Chip Hooper                 Tom Cain
# 1984               Thierry Tulasne                 Tom Cain
# 1985                 Robert Seguso              Jimmy Arias
# 1986                  Ulf Stenlund             Jeremy Bates
# 1987                  Bruno Oresar            Gary Donnelly
# 1988        Jean Philippe Fleurian             Mark Petchey
# 1989               Paul Chamberlin             Patrick Baur
# 1990               Paul Chamberlin           Danny Sapsford
# 1991             Francisco Montana             Jordi Arrese
# 1992                 Felipe Rivera         Richard Fromberg
# 1993                 Henri Leconte           Brian Devening
# 1994                 Greg Rusedski         Richard Krajicek
# 1995                 Greg Rusedski           Vincent Spadea
# 1996             Marcelo Filippini            Michael Joyce
# 1997               Patrick Mcenroe         Nicolas Lapentti
# 1998               John Van Lottum             Andrei Pavel
# 1999                   Andrew Ilie             Cecil Mamiit
# 2000                     Bob Bryan          Michael Russell
# 2001             Nikolay Davydenko    Franco Squillari [28]
# 2002               Agustin Calleri  Juan Ignacio Chela [19]
# 2003             Joachim Johansson              Dick Norman
# 2004              Marat Safin [13]          John Van Lottum
# 2005                     Noam Okun           Vincent Spadea
# 2006                 Jeff Morrison            Greg Rusedski
# 2007         Fernando Gonzalez [7]         Juan Monaco [32]
# 2008                 Brendan Evans            Igor Kunitsyn
# 2009               Dmitry Tursunov         Nicolas Lapentti
# 2010               Illya Marchenko            Ramon Delgado
# 2011                    Karol Beck              Lukas Lacko
# 2012             Mikhail Kukushkin        Alex Bogomolov Jr
# 2013                   Lukas Lacko           Carlos Berlocq
# 2014         Julien Benneteau [24]        Ivo Karlovic [29]
# 2015            Paul Henri Mathieu          Thomaz Bellucci
# 2016              Julien Benneteau         Santiago Giraldo
# 2017         Andreas Haider Maurer             Malek Jaziri
# 2018                       Unknown                  Unknown

# %% [markdown]
# ## WTA

# %%
wta = pd.concat([pd.read_csv('../data/tennis_wta-master/wta_matches_{0}.csv'.format(year), encoding='latin-1') for year in tqdm(range(1968, 2019))])

wta_slams = wta[wta['tourney_name'].isin(['Wimbledon', 'Roland Garros', 'French Open', 'US Open', 'Us Open', 'Australian Open'])]
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
#
#
#  35%|███▌      | 18/51 [00:00<00:00, 168.93it/s]
#
#
#  55%|█████▍    | 28/51 [00:00<00:00, 133.79it/s]
#
#
#  73%|███████▎  | 37/51 [00:00<00:00, 117.40it/s]
#
#
#  88%|████████▊ | 45/51 [00:00<00:00, 105.12it/s]
#
#
# 100%|██████████| 51/51 [00:00<00:00, 100.61it/s]

# %%
wta_slam_spoons = (
    wta_slams
        .groupby(['tourney_name', 'tourney_date'])
        .apply(lambda df: " ".join(spoon(df)))
        .reset_index()
        # Grab just the year from the int-formatted start date.
        .pipe(lambda df: df.assign(tourney_date=df.tourney_date.map(lambda v: str(v)[:4]).astype(int)))
        .rename(columns={'tourney_date': 'Year', 'tourney_name': 'Tournament', 0: 'Player'})
        # Recent US Opens are 'Us Open' for some reason.
        .replace('Us Open', 'US Open')
        .replace('Roland Garros', 'French Open')
        # Deal with doubled entries. The Australian was contested twice a couple of times due to calendar changes.
        # cf. http://www.mikero.com/misc/anti-slam/
        .groupby(['Tournament', 'Year'])
        .first()
        .unstack('Tournament')
        .replace(np.nan, 'Unknown')
        .applymap(lambda v: v.replace(" Unseeded", ""))    
)
# Out:
# WARNING: could not parse data for tourney French Open with timestamp 19700525
# WARNING: could not parse data for tourney French Open with timestamp 19720522
# WARNING: could not parse data for tourney US Open with timestamp 19800826
# WARNING: could not parse data for tourney Wimbledon with timestamp 19780626

# %%
wta_slam_spoons
# Out:
#                             Player                            \
# Tournament         Australian Open               French Open
# Year
# 1968                       Unknown          Sally Holdsworth
# 1969               Wendy Gilchrist           Erzsebet Polgar
# 1970                     L Cameron                   Unknown
# 1971                  Janet Fallis        Helga Masthoff [5]
# 1972                   Dorte Ekner                   Unknown
# 1973                 Frances Candy               Patti Hogan
# 1974                       Unknown             Linky Boshoff
# 1975              Helen Cawley [5]                Sue Mappin
# 1976                       Unknown          Iris Riedel Kuhn
# 1977               Kathleen Harter              Carrie Meyer
# 1978            Birgitte Hermansen               Chris Oneil
# 1979                       Unknown           Daniela Marzano
# 1980                   Diane Evers         Kim Jones Shaefer
# 1981                  Rosie Casals              Dana Gilbert
# 1982             Barbara Hallquist           Renata Tomanova
# 1983                     Beth Herr               Lele Forood
# 1984                  Wendy Prausa            Hana Fukarkova
# 1985                   Linda Gates              Iva Budarova
# 1986                       Unknown     Beverly Bowes Hackney
# 1987              Regina Marsikova        Pascale Etchemendy
# 1988         Dianne Balestrat [14]              Terry Phelps
# 1989                  Halle Cioffi          Nathalie Tauziat
# 1990             Janine Tremelling     Rosalyn Nideffer [13]
# 1991                 Patty Fendick        Isabelle Demongeot
# 1992                  Petra Thoren         Carrie Cunningham
# 1993                    Nana Smith                 Mana Endo
# 1994                   Lisa Mcshea   Catherine Mothes Jobkel
# 1995                    Nana Smith  Alexia Dechaume Balleret
# 1996              Sonya Jeyaseelan        Isabelle Demongeot
# 1997         Maria Sanchez Lorenzo          Rachel Mcquillan
# 1998                 Sandra Dopfer          Amelie Cocheteux
# 1999          Kimberly Po Messerli            Miriam Oremans
# 2000                Anna Smashnova          Barbara Schwartz
# 2001                 Adriana Gersi              Lisa Raymond
# 2002                   Mary Pierce    Stephanie Foretz Gacon
# 2003                Libuse Prusova         Bahia Mouhtassine
# 2004        Arantxa Parra Santonja           Mara Santangelo
# 2005               Tiffany Welford       Meghann Shaughnessy
# 2006                  Jill Craybas        Maria Vento Kabchi
# 2007              Catalina Castano        Caroline Wozniacki
# 2008               Laura Granville             Elena Vesnina
# 2009             Viktoria Kutuzova            Irena Pavlovic
# 2010                  Raluca Olaru           Alberta Brianti
# 2011                 Jamie Hampton            Junri Namigata
# 2012              Anna Chakvetadze              Alize Cornet
# 2013              Stefanie Voegele           Coco Vandeweghe
# 2014          Mariana Duque Marino           Luksika Kumkhum
# 2015                   Annika Beck           Evgeniya Rodina
# 2016               Klara Koukalova      Jelena Jankovic [23]
# 2017         Aliaksandra Sasnovich               Naomi Osaka
# 2018                 Shelby Rogers                   Unknown
#
#
# Tournament                   US Open                      Wimbledon
# Year
# 1968                     Mary Lowdon                 Gail Benedetti
# 1969                   Eva Lundquist               Kerstin Seelbach
# 1970                  Mary Struthers                Odile De Roubin
# 1971                    Lany Kaligis                     Helen Amos
# 1972           Maria Teresa Nasuelli                   Glynis Coles
# 1973               Sharon Walsh Pete               Gertruida Walhof
# 1974                      Janet Haas             Christina Sandberg
# 1975                   Mima Jausovec                 Terry Holladay
# 1976               Carrie Meyer [14]                 Florenta Mihai
# 1977                    Robin Harris                Kathleen Harter
# 1978                    Diane Desfor                        Unknown
# 1979                   Julie Anthony                Sue Barker [12]
# 1980                         Unknown                   Dana Gilbert
# 1981                  Lea Antonoplis             Claudia Casabianca
# 1982                Camille Benjamin                     Sue Barker
# 1983               Barbara Hallquist                 Debbie Freeman
# 1984                Julie Harrington                    Ginny Purdy
# 1985                Katerina Maleeva                  Masako Yanagi
# 1986               Nathalie Herreman          Beverly Bowes Hackney
# 1987                   Kathy Horvath                   Terry Phelps
# 1988             Mareen Louie Harper                 Shaun Stafford
# 1989                    Mercedes Paz                  Anne Meredith
# 1990                    Elise Burgin  Manuela Maleeva Fragniere [8]
# 1991                  Amanda Coetzer             Susan Sloane Lundy
# 1992               Tammy Whittington                Sarah Loosemore
# 1993                Caroline Kuhlman                Alexandra Fusai
# 1994                Janette Husarova         Bettina Fulco Villella
# 1995                Andrea Temesvari              Stephanie Rottier
# 1996                  Corina Morariu                Annabel Ellwood
# 1997                   Erika De Lone                 Ann Wunderlich
# 1998         Cristina Torrens Valero                   Nicole Pratt
# 1999                  Tatiana Panova           Magdalena Grzybowska
# 2000              Kristen Schlukebir                  Rita Kuti Kis
# 2001        Tamarine Tanasugarn [26]                Anne Keothavong
# 2002                  Shinobu Asagoe            Anna Smashnova [15]
# 2003           Eleni Daniilidou [25]         Virginia Ruano Pascual
# 2004           Stephanie Cohen Aloro               Gala Leon Garcia
# 2005                  Sandra Kloesel                    Emilie Loit
# 2006                Stephanie Dubois                    Camille Pin
# 2007              Yaroslava Shvedova           Anna Lena Groenefeld
# 2008                  Lucie Safarova         Nuria Llagostera Vives
# 2009                   Roberta Vinci                Alberta Brianti
# 2010                    Jill Craybas                   Ana Ivanovic
# 2011             Tamarine Tanasugarn             Yaroslava Shvedova
# 2012                   Julia Glushko          Monica Niculescu [29]
# 2013                 Chanel Simmonds             Irina Camelia Begu
# 2014                     Annika Beck                Taylor Townsend
# 2015           Karolina Pliskova [8]                 Sachia Vickery
# 2016                 Nadia Podoroska                  Camila Giorgi
# 2017                 Taylor Townsend               Yulia Putintseva
# 2018                         Unknown                        Unknown

# %%
winner_seed

# %% [markdown]
# PS: interesting properties of the wooden spoon --- https://web.archive.org/web/*/http://www.geocities.ws/andrewbroad/tennis/wooden_spoon/theory.html
